# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('Reagan_Corrected_API_values.csv')

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1)

# %%
df.head()
sample = df.sample(10).copy()

# %%
sample
# Out:
#                                      Filename         API  \
# 509            4238338334_UNIV_2_6_2H_LAS.las  4238338334
# 406     4238338096_UNIV_09_0906H_7528_1_2.las  4238338096
# 347        4238337812_UNIV_47_48_1802H_MD.las  4238337812
# 286         4238337661_UNIV_10_17_1H_temp.las  4238337661
# 103   4238336140UNIVERSITY_10_5_4_CNL_LAS.las  4238336140
# 102               4238336139PnrUniv2_3a_4.las  4238336139
# 235           4238337396_UNIV_10_19_3_cnl.las  4238337396
# 339              4238337802_UNIV_48_0703H.las  4238337802
# 457  4238338271_Univ_43_15_5H_Final_Gamma.las  4238338271
# 438            4238338223_UNIV_10_26_1SWD.las  4238338223
#
#                                                    LOC  GR  PE  NPHI  DPHI  \
# 509         Lat 31* 12' 8.38 N / Long 101* 46' 14.32 W   1   0     0     0
# 406   960.3' FWL & 450.8' FNL, SEC 9, BLK 9, UL SURVEY   0   0     0     0
# 347               lat 31 05 26.00     Lon 101 20 38.64   1   0     0     0
# ...

# %%
url = 'http://www.utlands.utsystem.edu/API/'
well = '4210542255'
full = url + well
full
# Out:
# 'http://www.utlands.utsystem.edu/API/4210542255'

# %%
page = requests.get(full)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    University Lands - Well Detail API: 42-105-42255
#   </title>
#   <link href="/Content/Images/favicon.png" rel="icon" type="image/png"/>
#   <!--[if IE]>
#     <link rel="shortcut icon" href="~/Content/Images/favicon.ico" type="image/vnd.microsoft.icon" />
#     <![endif]-->
#   <link href="https://fonts.googleapis.com/css?family=Roboto:700" rel="stylesheet"/>
#   <link href="/Content/css?v=_McdReewmD_AOoT8IYljIxJV-i6_93NuzMuMRLd1l281" rel="stylesheet">
#    <link href="/Content/css/bootstrap?v=BbR1Q4Z1nxkYEmEIRtLyNfB2yaG7TV_v0H2veIWn46A1" rel="stylesheet"/>
#    <script src="/bundles/clientscripts?v=444-cwC8O1SoC20WOSIiJg_QDD8xFJvkHOusSjMoItw1">
#    </script>
#   </link>
#  </head>
#  <body>
#   <div class="container main-content">
#    <div class="">
# ...

# %%
table = soup.find('table', class_= 'table table-bordered table-condensed table-responsive')
table = []

# %%
soup.find_all('tr')[0:3]
# Out:
# [<tr>
#  <td class="active"><strong>CBS:</strong></td>
#  <td>Crockett, Block 46, Section 04</td>
#  <td class="active"><strong>Location:</strong></td>
#  <td>2320 FNL &amp; 1720 FEL</td>
#  </tr>, <tr>
#  <td class="active"><strong>Total Depth:</strong></td>
#  <td>2343 feet</td>
#  <td class="active"><strong>Lat/Lon:</strong></td>
#  <td>30.99037317 / -101.36020163</td>
#  </tr>, <tr>
#  <td class="active"><strong>Elevation:</strong></td>
#  <td>GL 2577 feet</td>
#  <td class="active"><strong>NAD:</strong></td>
#  <td>NAD83</td>
#  </tr>]

# %%
df = pd.DataFrame(columns = ['API', 'Website', 'Block', 'Section', 'Latitude', 'Longitude', 'Field', 'Operator'])
df
# Out:
# Empty DataFrame
# Columns: [API, Website, Block, Section, Latitude, Longitude, Field, Operator]
# Index: []

# %%
ls = []
string = str(soup.find_all('tr')[0:1])
cleantext = BeautifulSoup(string, 'html').get_text().replace('\n', '')
print(cleantext)
print(ls)
# Out:
# [CBS:Crockett, Block 46, Section 04Location:2320 FNL & 1720 FEL]
# []

# %%
ls = [cleantext[30]]
ls = []
bool(ls) == False
# Out:
# True

# %%
ls = [well, full]
soupstring = str(soup.find_all('tr')[0:1])
cleantext = BeautifulSoup(soupstring, 'html').get_text().replace('\n', '')
ls.extend([cleantext[21:23], cleantext[33:35]])
soupstring = str(soup.find_all('tr')[1:2])
cleantext = BeautifulSoup(soupstring, 'html').get_text().replace('\n', '')
ls.extend([cleantext[31:42], cleantext[45:58]])
ls.extend([cleantext[30:41], cleantext[44:57]])
ls[-1][0]
ls
# Out:
# ['4246138073',
#  'http://www.utlands.utsystem.edu/API/4246138073',
#  ' S',
#  'oc',
#  '1.20249595 ',
#  '101.80658747]',
#  '31.20249595',
#  '-101.80658747']

# %%
ls[-2][0]
# Out:
# '3'
